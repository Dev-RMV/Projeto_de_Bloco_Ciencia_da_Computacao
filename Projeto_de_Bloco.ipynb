# %%
from add_node import add_node
import numpy as np

# %%
lista = list(np.random.randint(low=-10000, high=10000, size=10000, dtype="int16"))
lista
# Out:
# [np.int16(-2884),
#  np.int16(9487),
#  np.int16(6252),
#  np.int16(328),
#  np.int16(-2301),
#  np.int16(-8990),
#  np.int16(-1132),
#  np.int16(-5911),
#  np.int16(7146),
#  np.int16(-6650),
#  np.int16(452),
#  np.int16(-259),
#  np.int16(4675),
#  np.int16(-3090),
#  np.int16(262),
#  np.int16(1100),
#  np.int16(9867),
#  np.int16(3019),
#  np.int16(5958),
#  np.int16(-5433),
#  np.int16(-5900),
#  np.int16(4125),
#  np.int16(-2512),
#  np.int16(4812),
#  np.int16(-8799),
#  np.int16(6641),
#  np.int16(9965),
#  np.int16(6167),
#  np.int16(4680),
#  np.int16(-8474),
#  np.int16(-9822),
#  np.int16(-1401),
#  np.int16(5917),
#  np.int16(-2749),
#  np.int16(-411),
#  np.int16(2520),
#  np.int16(6455),
#  np.int16(9334),
#  np.int16(-6865),
#  np.int16(8630),
#  np.int16(7171),
#  np.int16(-1874),
#  np.int16(-3914),
#  np.int16(-952),
#  np.int16(4323),
#  np.int16(3650),
#  np.int16(-9568),
#  np.int16(-7453),
#  np.int16(5616),
#  np.int16(7979),
#  np.int16(-6485),
# ...

# %%
head=None
lista2=[]
for j in range(len(lista)):
    head = add_node(head, lista[j])
    print('Numero de Nodes:', head.no_of_nodes)
# Out:
# Numero de Nodes: 1
# Numero de Nodes: 2
# Numero de Nodes: 3
# Numero de Nodes: 4
# Numero de Nodes: 5
# Numero de Nodes: 6
# Numero de Nodes: 7
# Numero de Nodes: 8
# Numero de Nodes: 9
# Numero de Nodes: 10
# Numero de Nodes: 11
# Numero de Nodes: 12
# Numero de Nodes: 13
# Numero de Nodes: 14
# Numero de Nodes: 15
# Numero de Nodes: 16
# Numero de Nodes: 17
# Numero de Nodes: 18
# Numero de Nodes: 19
# Numero de Nodes: 20
# Numero de Nodes: 21
# Numero de Nodes: 22
# Numero de Nodes: 23
# Numero de Nodes: 24
# Numero de Nodes: 25
# Numero de Nodes: 26
# Numero de Nodes: 27
# Numero de Nodes: 28
# Numero de Nodes: 29
# Numero de Nodes: 30
# Numero de Nodes: 31
# Numero de Nodes: 32
# Numero de Nodes: 33
# Numero de Nodes: 34
# Numero de Nodes: 35
# Numero de Nodes: 36
# Numero de Nodes: 37
# Numero de Nodes: 38
# Numero de Nodes: 39
# Numero de Nodes: 40
# Numero de Nodes: 41
# Numero de Nodes: 42
# Numero de Nodes: 43
# Numero de Nodes: 44
# Numero de Nodes: 45
# ...

# %%
lista.sort()

# %%
head2=head
for i in range(len(lista)):
    lista2.append(head2.data)
    head2 = head2.next

# %%
print(lista)
print('------------------------')
print(lista2)
# Out:
# [np.int16(-10000), np.int16(-9999), np.int16(-9997), np.int16(-9996), np.int16(-9993), np.int16(-9992), np.int16(-9988), np.int16(-9988), np.int16(-9982), np.int16(-9981), np.int16(-9981), np.int16(-9979), np.int16(-9979), np.int16(-9977), np.int16(-9976), np.int16(-9975), np.int16(-9971), np.int16(-9965), np.int16(-9964), np.int16(-9960), np.int16(-9958), np.int16(-9956), np.int16(-9951), np.int16(-9951), np.int16(-9948), np.int16(-9947), np.int16(-9943), np.int16(-9943), np.int16(-9941), np.int16(-9939), np.int16(-9939), np.int16(-9936), np.int16(-9933), np.int16(-9932), np.int16(-9932), np.int16(-9931), np.int16(-9930), np.int16(-9929), np.int16(-9928), np.int16(-9926), np.int16(-9925), np.int16(-9923), np.int16(-9920), np.int16(-9917), np.int16(-9914), np.int16(-9913), np.int16(-9913), np.int16(-9911), np.int16(-9909), np.int16(-9904), np.int16(-9903), np.int16(-9902), np.int16(-9902), np.int16(-9898), np.int16(-9897), np.int16(-9896), np.int16(-9895), np.int16(-9894), np.int16(-
# ...

# %%
print('As listas sao iguais? ',lista == lista2)
# Out:
# As listas sao iguais?  True
